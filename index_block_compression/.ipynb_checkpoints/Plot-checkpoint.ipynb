# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# x axis is ra, y axis is cr
Baseline_x = [4114.4,4494.2,4700.6,5532.3,7390.3,11475.2]
Baseline_y = [87.9,51.6,33.5,24.5,19.9,17.7]

# %%
Leco_x = [3700.43,
3350.06,
2821.2,
2291.99,
1762.47,
1234.14]
Leco_y = [41.9273,
43.3265,
46.1289,
51.7296,
62.9351,
85.3461]

# %%
baseline = plt.plot(Baseline_x, Baseline_y, label = 'baseline')
plt.scatter(Baseline_x, Baseline_y)
leco = plt.plot(Leco_x, Leco_y, label = 'leco')
plt.scatter(Leco_x, Leco_y)
plt.xlim(0, 12000)
plt.ylim(0,100)
plt.xlabel('random access')
plt.ylabel('compression rate')
plt.title('wholestring_max_30_sep_key.txt')
plt.show()

# %%
Baseline_x =[4177.86,
4333.61,
4704.74,
5558.1,
7438.09,
11260.9]
Baseline_y = [63.17,
38.5,
26.26,
20,
16.87,
15.33]

# %%
Leco_x = [912.604,
912.897,
782.195,
782.521,
782.064,
782.195,
651.948]
Leco_y = [27.381,
27.7961,
28.6245,
30.2813,
33.5966,
40.2255,
53.4834]

# %%
baseline = plt.plot(Baseline_x, Baseline_y, label = 'baseline')
plt.scatter(Baseline_x, Baseline_y)
leco = plt.plot(Leco_x, Leco_y, label = 'leco')
plt.scatter(Leco_x, Leco_y)
plt.xlim(0, 12000)
plt.ylim(0,100)
plt.xlabel('random access')
plt.ylabel('compression rate')
plt.title('poisson_20000_sep_key.txt')
plt.show()

# %%
# wholestring_min_12_max_24_datablock_i3db
Baseline_x = [620.24,
613.208,
639.967,
730.758,
941.082,
1429.1]
Baseline_y = [87.0756,
51.979,
34.4183,
25.6314,
21.238,
19.0442]
Leco_x = [501.948,
537.211,
626.248,
706.198,
846.603,
938.671]
Leco_y = [84.2907,
65.0553,
55.4375,
50.6274,
48.2223,
47.021]

# %%
# poisson_2000000_key_i3db
Baseline_x = [455.201,
495.95,
526.863,
622.28,
796.702,
1167.48]
Baseline_y = [87.4018,
56.6585,
41.2843,
33.5994,
29.7551,
27.8339]
Leco_x = [268.922,
276.669,
290.465,
305.629,
324.033,
342.332]
Leco_y = [58.2634,
44.9817,
38.3408,
35.0204,
33.3602,
32.531]

# %%
# wholestring_min_12_max_24_datablock_ecs.i3g.2xlarge
Baseline_x = [595.978,
598.082,
626.507,
680.592,
830.419,
1160.18]
Baseline_y = [87.0756,
51.979,
34.4183,
25.6314,
21.238,
19.0442]
Leco_x = [528.499,
598.29,
673.882,
761.898,
849.586,
936.423]
Leco_y = [84.2907,
65.0553,
55.4375,
50.6274,
48.2223,
47.021]

# %%
# poisson_2000000_datablock_ecs.i3g.2xlarge
Baseline_x = [768.93,
766.924,
793.202,
842.641,
982.198,
1266.29]
Baseline_y = [85.8425,
51.6349,
34.5303,
25.9781,
21.702,
19.5625]
Leco_x = [597.143,
590.586,
606.785,
622.82,
644.267,
662.654]
Leco_y = [59.5029,
44.5778,
37.1153,
33.385,
31.5189,
30.5858]

# %%
def plot_cr_ra(Baseline_x, Baseline_y, Leco_x, Leco_y, title,scale):
    baseline, = plt.plot(Baseline_x, Baseline_y, label = 'baseline')
    plt.scatter(Baseline_x, Baseline_y)
    leco, = plt.plot(Leco_x, Leco_y, label = 'leco')
    plt.legend(handles=[baseline, leco])
    plt.scatter(Leco_x, Leco_y)
    plt.xlim(0, scale)
    plt.ylim(0,100)
    plt.xlabel('random access')
    plt.ylabel('compression rate')
    plt.title(title)
    plt.show()

# %%
plot_cr_ra(Baseline_x, Baseline_y, Leco_x, Leco_y,'wholestring_min_12_max_24_datablock_ecs.i3g.2xlarge',1200)

# %%
plot_cr_ra(Baseline_x, Baseline_y, Leco_x, Leco_y,'wholestring_min_12_max_24_datablock_i3db',1500)

# %%
plot_cr_ra(Baseline_x, Baseline_y, Leco_x, Leco_y,'poisson_2000000_datablock_ecs.i3g.2xlarge',1300)

# %%
plot_cr_ra(Baseline_x, Baseline_y, Leco_x, Leco_y,'poisson_2000000_key_i3db',1300)

# %%
# wholestring_min_12_max_24_datablock_i3db
Baseline_x = [575.738,
594.143,
626.131,
716.337,
903.539,
1318.56]
Baseline_y = [87.0756,
51.979,
34.4183,
25.6314,
21.238,
19.0442]
Leco_x = [372.427,
374.572,
376.778,
390.542,
402.465,
410.303]
Leco_y = [82.1974,
62.9619,
53.3442,
48.534,
46.129,
44.9277]

# %%
plot_cr_ra(Baseline_x, Baseline_y, Leco_x, Leco_y,'wholestring_min_12_max_24_datablock_i3db',1400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-693f32693e71> in <module>
# ----> 1 plot_cr_ra(Baseline_x, Baseline_y, Leco_x, Leco_y,'wholestring_min_12_max_24_datablock_i3db',1400)
#
# NameError: name 'plot_cr_ra' is not defined
